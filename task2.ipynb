# %%
import pandas as pd
from nltk import sent_tokenize, word_tokenize
from nltk.stem import PorterStemmer as p_stem

# %%
df = pd.read_csv("sentiment_analysis.csv")
# df
df.shape
# Out:
# (499, 7)

# %%
text_data = df['text']
text_data
# Out:
# 0                  What a great day!!! Looks like dream.
# 1         I feel sorry, I miss you here in the sea beach
# 2                                         Don't angry me
# 3      We attend in the class just for listening teac...
# 4                      Those who want to go, let them go
#                              ...
# 494    According to , a quarter of families under six...
# 495        the plan to not spend money is not going well
# 496      uploading all my bamboozle pictures of facebook
# 497     congratulations ! you guys finish a month ear...
# 498     actually, I wish I was back in Tahoe.  I miss...
# Name: text, Length: 499, dtype: object

# %%
for row in text_data:
    tokens = word_tokenize(row)
    print("Original Tokens:", tokens)

    stemmed_tokens = [p_stem().stem(token) for token in tokens]
    print("Stemmed Tokens:", stemmed_tokens)
    print("\n")
# Out:
# Original Tokens: ['What', 'a', 'great', 'day', '!', '!', '!', 'Looks', 'like', 'dream', '.']
# Stemmed Tokens: ['what', 'a', 'great', 'day', '!', '!', '!', 'look', 'like', 'dream', '.']
#
#
# Original Tokens: ['I', 'feel', 'sorry', ',', 'I', 'miss', 'you', 'here', 'in', 'the', 'sea', 'beach']
# Stemmed Tokens: ['i', 'feel', 'sorri', ',', 'i', 'miss', 'you', 'here', 'in', 'the', 'sea', 'beach']
#
#
# Original Tokens: ['Do', "n't", 'angry', 'me']
# Stemmed Tokens: ['do', "n't", 'angri', 'me']
#
#
# Original Tokens: ['We', 'attend', 'in', 'the', 'class', 'just', 'for', 'listening', 'teachers', 'reading', 'on', 'slide', '.', 'Just', 'Nonsence']
# Stemmed Tokens: ['we', 'attend', 'in', 'the', 'class', 'just', 'for', 'listen', 'teacher', 'read', 'on', 'slide', '.', 'just', 'nonsenc']
#
#
# Original Tokens: ['Those', 'who', 'want', 'to', 'go', ',', 'let', 'them', 'go']
# Stemmed Tokens: ['those', 'who', 'want', 'to', 'go', ',', 'let', 'them', 'go']
#
#
# Original Tokens: ['Its', 'night', '2', 'am', ',', 'feeling', 'neutral']
# Stemmed Tokens: ['it', 'night', '2', 'am', ',', 'feel', 'neutral']
#
#
# Original Tokens: ['2', 'am', 'feedings', 'for', 'the', 'baby', 'are', 'fun', 'when', 'he', 'is', 'all', 'smiles', 'and', 'coos']
# Stemmed Tokens: ['2', 'am', 'feed', 'for', 'the', 'babi', 'are', 'fun', 'when', 'he', 'is', 'all', 'smile', 'and', 'coo']
#
#
# Original Tokens: ['Soooo', 'high']
# Stemmed Tokens: ['soooo', 'high']
#
#
# Original Tokens: ['Both', 'of', 'you']
# Stemmed Tokens: ['both', 'of', 'you']
#
#
# Original Tokens: ['Today', 'first', 'time', 'I', 'arrive', 'in', 'the', 'boat', '.', 'Its', 'amazing', 'journey']
# Stemmed Tokens: ['today', 'first', 'time', 'i', 'arriv', 'in', 'the', 'boat', '.', 'it', 'amaz', 'journey']
#
#
# Original Tokens: ['Love', 'is', 'something', 'like', 'E=MC^2', 'rules']
# Stemmed Tokens: ['love', 'is', 'someth', 'like', 'e=mc^2', 'rule']
#
#
# Original Tokens: ['I', 'really', 'really', 'like', 'the', 'song', 'Cardigan', 'by', 'Taylor', 'Swift']
# Stemmed Tokens: ['i', 'realli', 'realli', 'like', 'the', 'song', 'cardigan', 'by', 'taylor', 'swift']
#
#
# Original Tokens: ['My', 'Sharpie', 'is', 'running', 'DANGERously', 'low', 'on', 'ink']
# Stemmed Tokens: ['my', 'sharpi', 'is', 'run', 'danger', 'low', 'on', 'ink']
#
#
# Original Tokens: ['i', 'want', 'to', 'go', 'to', 'music', 'tonight', 'but', 'i', 'lost', 'my', 'voice', '.']
# Stemmed Tokens: ['i', 'want', 'to', 'go', 'to', 'music', 'tonight', 'but', 'i', 'lost', 'my', 'voic', '.']
#
#
# Original Tokens: ['Always', 'somewhere', 'I', 'miss', 'you', 'where', 'I', 'have', 'been']
# Stemmed Tokens: ['alway', 'somewher', 'i', 'miss', 'you', 'where', 'i', 'have', 'been']
#
#
# Original Tokens: ['Do', "n't", 'distrube', 'me']
# Stemmed Tokens: ['do', "n't", 'distrub', 'me']
#
#
# Original Tokens: ['I', 'do', "n't", 'care', ',', 'who', 'are', 'you', 'and', 'what', 'can', 'you', 'do']
# Stemmed Tokens: ['i', 'do', "n't", 'care', ',', 'who', 'are', 'you', 'and', 'what', 'can', 'you', 'do']
#
#
# Original Tokens: ['i', '`', 've', 'been', 'sick', 'for', 'the', 'past', 'few', 'days']
# Stemmed Tokens: ['i', '`', 've', 'been', 'sick', 'for', 'the', 'past', 'few', 'day']
#
#
# Original Tokens: ['I', "'m", 'come', 'back', 'home', ',', 'my', 'past', 'job', ',', 'its', 'really', 'good', 'time', 'for', 'me']
# Stemmed Tokens: ['i', "'m", 'come', 'back', 'home', ',', 'my', 'past', 'job', ',', 'it', 'realli', 'good', 'time', 'for', 'me']
#
#
# Original Tokens: ['I', 'will', 'never', 'fall', 'in', 'love', 'until', 'I', 'found', 'you']
# Stemmed Tokens: ['i', 'will', 'never', 'fall', 'in', 'love', 'until', 'i', 'found', 'you']
#
#
# Original Tokens: ['oh', 'Maya', ',', 'I', '`', 'm', 'so', 'sorry', '!', '!', 'I', 'hope', 'you', 'find', 'her', 'soon', '!', '!']
# Stemmed Tokens: ['oh', 'maya', ',', 'i', '`', 'm', 'so', 'sorri', '!', '!', 'i', 'hope', 'you', 'find', 'her', 'soon', '!', '!']
#
#
# Original Tokens: ['Playing', 'with', 'kids', ',', 'its', 'amazing']
# Stemmed Tokens: ['play', 'with', 'kid', ',', 'it', 'amaz']
#
#
# Original Tokens: ['is', 'cleaning', 'the', 'house', 'for', 'her', 'family', 'who', 'is', 'comming', 'later', 'today', '..']
# Stemmed Tokens: ['is', 'clean', 'the', 'hous', 'for', 'her', 'famili', 'who', 'is', 'com', 'later', 'today', '..']
#
#
# Original Tokens: ['I', 'tried', 'to', 'shtdown', 'my', 'pc', 'and', 'accenditenly', 'I', 'click', 'in', 'the', 'restart', 'button', '.', 'Its', 'really', 'disgusting']
# Stemmed Tokens: ['i', 'tri', 'to', 'shtdown', 'my', 'pc', 'and', 'accenditenli', 'i', 'click', 'in', 'the', 'restart', 'button', '.', 'it', 'realli', 'disgust']
#
#
# Original Tokens: ['Follow', 'me', ',', 'I', 'will', 'follow', 'you', 'too']
# Stemmed Tokens: ['follow', 'me', ',', 'i', 'will', 'follow', 'you', 'too']
#
#
# Original Tokens: ['Its', 'amazing', 'game', ',', 'I', 'playing', 'everyday']
# Stemmed Tokens: ['it', 'amaz', 'game', ',', 'i', 'play', 'everyday']
#
#
# Original Tokens: ['I', '`', 'm', 'sorry', '.']
# Stemmed Tokens: ['i', '`', 'm', 'sorri', '.']
#
#
# Original Tokens: ['I', "'m", 'in', 'the', 'village', 'now', 'and', 'there', 'hardly', 'found', 'internate', ',', 'feeling', 'gloomy']
# Stemmed Tokens: ['i', "'m", 'in', 'the', 'villag', 'now', 'and', 'there', 'hardli', 'found', 'intern', ',', 'feel', 'gloomi']
#
#
# Original Tokens: ['juss', 'came', 'back', 'from', 'Barisal']
# Stemmed Tokens: ['juss', 'came', 'back', 'from', 'baris']
#
#
# Original Tokens: ['Went', 'to', 'sleep', 'and', 'there', 'is', 'a', 'power', 'cut', 'in', 'the', 'village', '.']
# Stemmed Tokens: ['went', 'to', 'sleep', 'and', 'there', 'is', 'a', 'power', 'cut', 'in', 'the', 'villag', '.']
#
#
# Original Tokens: ['How', 'looks', 'like', 'our', 'company', 'new', 'logo', '?']
# Stemmed Tokens: ['how', 'look', 'like', 'our', 'compani', 'new', 'logo', '?']
#
#
# Original Tokens: ['I', 'buy', 'Sophie', "'s", 'world', 'book', ',', 'I', "'m", 'really', 'so', 'happy']
# Stemmed Tokens: ['i', 'buy', 'sophi', "'s", 'world', 'book', ',', 'i', "'m", 'realli', 'so', 'happi']
#
#
# Original Tokens: ['If', 'it', 'is', 'any', 'consolation', 'I', 'got', 'my', 'BMI', 'tested', 'hahaha', 'it', 'says', 'I', 'am', 'obesed', 'well', 'so', 'much', 'for', 'being', 'unhappy', 'for', 'about', '10', 'minutes', '.']
# Stemmed Tokens: ['if', 'it', 'is', 'ani', 'consol', 'i', 'got', 'my', 'bmi', 'test', 'hahaha', 'it', 'say', 'i', 'am', 'obes', 'well', 'so', 'much', 'for', 'be', 'unhappi', 'for', 'about', '10', 'minut', '.']
#
#
# Original Tokens: ['That', '`', 's', 'very', 'funny', '.', 'Cute', 'kids', '.']
# Stemmed Tokens: ['that', '`', 's', 'veri', 'funni', '.', 'cute', 'kid', '.']
#
#
# Original Tokens: ['Ahhh', ',', 'I', 'slept', 'through', 'the', 'game', '.', 'I', '`', 'm', 'gon', 'na', 'try', 'my', 'best', 'to', 'watch', 'tomorrow', 'though', '.', 'I', 'hope', 'we', 'play', 'Army', '.']
# Stemmed Tokens: ['ahhh', ',', 'i', 'slept', 'through', 'the', 'game', '.', 'i', '`', 'm', 'gon', 'na', 'tri', 'my', 'best', 'to', 'watch', 'tomorrow', 'though', '.', 'i', 'hope', 'we', 'play', 'armi', '.']
#
#
# Original Tokens: ['My', 'semester', 'final', 'exam', 'is', 'complete', '.', 'Hurray', '!', '!', '!']
# Stemmed Tokens: ['my', 'semest', 'final', 'exam', 'is', 'complet', '.', 'hurray', '!', '!', '!']
#
#
# Original Tokens: ['Born', 'and', 'raised', 'in', 'NYC', 'and', 'living', 'in', 'Texas', 'for', 'the', 'past', '10', 'years', '!', 'I', 'still', 'miss', 'NY']
# Stemmed Tokens: ['born', 'and', 'rais', 'in', 'nyc', 'and', 'live', 'in', 'texa', 'for', 'the', 'past', '10', 'year', '!', 'i', 'still', 'miss', 'ny']
#
#
# Original Tokens: ['just', 'in', 'case', 'you', 'wonder', ',', 'we', 'are', 'really', 'busy', 'today', 'and', 'this', 'coming', 'with', 'with', 'adding', 'tons', 'of', 'new', 'blogs', 'and', 'updates', 'stay', 'tuned']
# Stemmed Tokens: ['just', 'in', 'case', 'you', 'wonder', ',', 'we', 'are', 'realli', 'busi', 'today', 'and', 'thi', 'come', 'with', 'with', 'ad', 'ton', 'of', 'new', 'blog', 'and', 'updat', 'stay', 'tune']
#
#
# Original Tokens: ['i', '`', 'm', 'soooooo', 'sleeeeepy', '!', '!', '!', 'the', 'last', 'day', 'o', '`', 'school', 'was', 'today', '....', 'sniffle', '....']
# Stemmed Tokens: ['i', '`', 'm', 'soooooo', 'sleeeeepi', '!', '!', '!', 'the', 'last', 'day', 'o', '`', 'school', 'wa', 'today', '....', 'sniffl', '....']
#
#
# Original Tokens: ['romance', 'zero', 'is', 'funny']
# Stemmed Tokens: ['romanc', 'zero', 'is', 'funni']
#
#
# Original Tokens: ['Car', 'not', 'happy', ',', 'big', 'big', 'dent', 'in', 'boot', '!', 'Hoping', 'theyre', 'not', 'going', 'to', 'write', 'it', 'off', ',', 'crossing', 'fingers', 'and', 'waiting']
# Stemmed Tokens: ['car', 'not', 'happi', ',', 'big', 'big', 'dent', 'in', 'boot', '!', 'hope', 'theyr', 'not', 'go', 'to', 'write', 'it', 'off', ',', 'cross', 'finger', 'and', 'wait']
#
#
# Original Tokens: ['Yor', 'are', 'so', 'unromantic']
# Stemmed Tokens: ['yor', 'are', 'so', 'unromant']
#
#
# Original Tokens: ['MAYDAY', '?', '!']
# Stemmed Tokens: ['mayday', '?', '!']
#
#
# Original Tokens: ['I', '`', 'd', 'rather', 'do', 'the', 'early', 'run', '..', 'but', 'I', 'am', 'a', 'morning', 'runner']
# Stemmed Tokens: ['i', '`', 'd', 'rather', 'do', 'the', 'earli', 'run', '..', 'but', 'i', 'am', 'a', 'morn', 'runner']
#
#
# Original Tokens: ['I', 'love', 'to', '!', 'But', 'I', '`', 'm', 'only', 'available', 'from', '5pm', '.', 'and', 'where', 'dear', '?']
# Stemmed Tokens: ['i', 'love', 'to', '!', 'but', 'i', '`', 'm', 'onli', 'avail', 'from', '5pm', '.', 'and', 'where', 'dear', '?']
#
#
# Original Tokens: ['The', 'girl', 'in', 'the', 'hair', 'salon', 'asked', 'me', "'Shall", 'I', 'trim', 'your', 'eyebrows', '!', "'", 'How', 'old', 'do', 'I', 'feel', '?']
# Stemmed Tokens: ['the', 'girl', 'in', 'the', 'hair', 'salon', 'ask', 'me', "'shall", 'i', 'trim', 'your', 'eyebrow', '!', "'", 'how', 'old', 'do', 'i', 'feel', '?']
#
#
# Original Tokens: ['i', 'talk', 'to', 'you']
# Stemmed Tokens: ['i', 'talk', 'to', 'you']
#
#
# Original Tokens: ['im', 'soo', 'bored', ',', 'I', 'do', "n't", 'like', 'this', 'music', 'video']
# Stemmed Tokens: ['im', 'soo', 'bore', ',', 'i', 'do', "n't", 'like', 'thi', 'music', 'video']
#
#
# Original Tokens: ['this', 'concert', 'is', 'amazing']
# Stemmed Tokens: ['thi', 'concert', 'is', 'amaz']
#
#
# Original Tokens: ['Had', 'nicotine', 'replacement', 'patch', 'on', 'for', '4', 'hours', '.', 'So', 'far', ',', 'so', 'good', ',', 'but', 'I', 'did', 'sleep', 'for', 'most', 'of', 'those', '4', 'hours', '.', 'Getting', 'a', 'bit', 'twitchy', 'now']
# Stemmed Tokens: ['had', 'nicotin', 'replac', 'patch', 'on', 'for', '4', 'hour', '.', 'so', 'far', ',', 'so', 'good', ',', 'but', 'i', 'did', 'sleep', 'for', 'most', 'of', 'those', '4', 'hour', '.', 'get', 'a', 'bit', 'twitchi', 'now']
#
#
# Original Tokens: ['Its', 'raining', ',', 'I', 'need', 'an', 'umbrella']
# Stemmed Tokens: ['it', 'rain', ',', 'i', 'need', 'an', 'umbrella']
#
#
# Original Tokens: ['should', 'be', 'sleeping', '.', 'lost', 'my', 'voice', 'a', 'couple', 'day', 'ago', '.']
# Stemmed Tokens: ['should', 'be', 'sleep', '.', 'lost', 'my', 'voic', 'a', 'coupl', 'day', 'ago', '.']
#
#
# Original Tokens: ['I', "'m", 'depressed', ',', 'I', "'m", 'thinking', 'about', 'suicide', ',', 'what', 'I', 'need', 'to', 'do', 'now', '?']
# Stemmed Tokens: ['i', "'m", 'depress', ',', 'i', "'m", 'think', 'about', 'suicid', ',', 'what', 'i', 'need', 'to', 'do', 'now', '?']
#
#
# Original Tokens: ['I', '`', 've', 'heard', 'this', 'fall', '.', 'I', '`', 'm', 'waiting', 'too', '!']
# Stemmed Tokens: ['i', '`', 've', 'heard', 'thi', 'fall', '.', 'i', '`', 'm', 'wait', 'too', '!']
#
#
# Original Tokens: ['I', 'saw', 'an', 'amazing', 'nightmare', 'yesterday', 'night']
# Stemmed Tokens: ['i', 'saw', 'an', 'amaz', 'nightmar', 'yesterday', 'night']
#
#
# Original Tokens: ['I', 'AM', 'SUCH', 'A', 'CREEPER', 'I', 'feel', 'disappointed', 'because', 'of', 'it', '.']
# Stemmed Tokens: ['i', 'am', 'such', 'a', 'creeper', 'i', 'feel', 'disappoint', 'becaus', 'of', 'it', '.']
#
#
# Original Tokens: ['I', 'have', 'bad', 'headech', ',', 'what', 'I', 'need', 'to', 'do', 'now']
# Stemmed Tokens: ['i', 'have', 'bad', 'headech', ',', 'what', 'i', 'need', 'to', 'do', 'now']
#
#
# Original Tokens: ['happy', 'mother', '`', 's', 'day', 'to', 'all', 'moms', 'out', 'there', '.', 'Mothers', 'are', 'our', 'real', 'hero']
# Stemmed Tokens: ['happi', 'mother', '`', 's', 'day', 'to', 'all', 'mom', 'out', 'there', '.', 'mother', 'are', 'our', 'real', 'hero']
#
#
# Original Tokens: ['Grabbing', 'coffee', 'from', 'then', 'making', 'mom', 'breakfast']
# Stemmed Tokens: ['grab', 'coffe', 'from', 'then', 'make', 'mom', 'breakfast']
#
#
# Original Tokens: ['im', 'thinking', 'that', 'im', 'going', 'to', 'have', 'fun', 'tonight']
# Stemmed Tokens: ['im', 'think', 'that', 'im', 'go', 'to', 'have', 'fun', 'tonight']
#
#
# Original Tokens: ['Yesterday', 'was', 'most', 'valuable', 'day', 'for', 'me']
# Stemmed Tokens: ['yesterday', 'wa', 'most', 'valuabl', 'day', 'for', 'me']
#
#
# Original Tokens: ['Haha', 'I', 'know', ',', 'I', 'cant', 'handle', 'the', 'fame', '!', 'and', 'thank', 'you', '!']
# Stemmed Tokens: ['haha', 'i', 'know', ',', 'i', 'cant', 'handl', 'the', 'fame', '!', 'and', 'thank', 'you', '!']
#
#
# Original Tokens: ['One', 'suggestion', 'for', 'me', 'is', ',', 'be', 'up', 'to', 'date']
# Stemmed Tokens: ['one', 'suggest', 'for', 'me', 'is', ',', 'be', 'up', 'to', 'date']
#
#
# Original Tokens: ['Always', 'love', 'everyone', ',', 'love', 'all', 'animals', '.', 'Most', 'important', 'love', 'your', 'parents']
# Stemmed Tokens: ['alway', 'love', 'everyon', ',', 'love', 'all', 'anim', '.', 'most', 'import', 'love', 'your', 'parent']
#
#
# Original Tokens: ['I', "'m", 'playing', 'minecraft', 'video', 'game', '.', 'I', "'m", 'addicated', 'to', 'it', '.']
# Stemmed Tokens: ['i', "'m", 'play', 'minecraft', 'video', 'game', '.', 'i', "'m", 'addic', 'to', 'it', '.']
#
#
# Original Tokens: ['See', 'you', 'in', 'the', 'cloud']
# Stemmed Tokens: ['see', 'you', 'in', 'the', 'cloud']
#
#
# Original Tokens: ['What', 'a', 'great', 'day', '!', '!', '!', 'Looks', 'like', 'dream', '.']
# Stemmed Tokens: ['what', 'a', 'great', 'day', '!', '!', '!', 'look', 'like', 'dream', '.']
#
#
# Original Tokens: ['I', 'feel', 'sorry', ',', 'I', 'miss', 'you', 'here', 'in', 'the', 'sea', 'beach']
# Stemmed Tokens: ['i', 'feel', 'sorri', ',', 'i', 'miss', 'you', 'here', 'in', 'the', 'sea', 'beach']
#
#
# Original Tokens: ['Do', "n't", 'angry', 'me']
# Stemmed Tokens: ['do', "n't", 'angri', 'me']
#
#
# Original Tokens: ['We', 'attend', 'in', 'the', 'class', 'just', 'for', 'listening', 'teachers', 'reading', 'on', 'slide', '.', 'Just', 'Nonsence']
# Stemmed Tokens: ['we', 'attend', 'in', 'the', 'class', 'just', 'for', 'listen', 'teacher', 'read', 'on', 'slide', '.', 'just', 'nonsenc']
#
#
# Original Tokens: ['Those', 'who', 'want', 'to', 'go', ',', 'let', 'them', 'go']
# Stemmed Tokens: ['those', 'who', 'want', 'to', 'go', ',', 'let', 'them', 'go']
#
#
# Original Tokens: ['Its', 'night', '2', 'am', ',', 'feeling', 'neutral']
# Stemmed Tokens: ['it', 'night', '2', 'am', ',', 'feel', 'neutral']
#
#
# Original Tokens: ['2', 'am', 'feedings', 'for', 'the', 'baby', 'are', 'fun', 'when', 'he', 'is', 'all', 'smiles', 'and', 'coos']
# Stemmed Tokens: ['2', 'am', 'feed', 'for', 'the', 'babi', 'are', 'fun', 'when', 'he', 'is', 'all', 'smile', 'and', 'coo']
#
#
# Original Tokens: ['Soooo', 'high']
# Stemmed Tokens: ['soooo', 'high']
#
#
# Original Tokens: ['Both', 'of', 'you']
# Stemmed Tokens: ['both', 'of', 'you']
#
#
# Original Tokens: ['Today', 'first', 'time', 'I', 'arrive', 'in', 'the', 'boat', '.', 'Its', 'amazing', 'journey']
# Stemmed Tokens: ['today', 'first', 'time', 'i', 'arriv', 'in', 'the', 'boat', '.', 'it', 'amaz', 'journey']
#
#
# Original Tokens: ['Love', 'is', 'something', 'like', 'E=MC^2', 'rules']
# Stemmed Tokens: ['love', 'is', 'someth', 'like', 'e=mc^2', 'rule']
#
#
# Original Tokens: ['I', 'really', 'really', 'like', 'the', 'song', 'Cardigan', 'by', 'Taylor', 'Swift']
# Stemmed Tokens: ['i', 'realli', 'realli', 'like', 'the', 'song', 'cardigan', 'by', 'taylor', 'swift']
#
#
# Original Tokens: ['My', 'Sharpie', 'is', 'running', 'DANGERously', 'low', 'on', 'ink']
# Stemmed Tokens: ['my', 'sharpi', 'is', 'run', 'danger', 'low', 'on', 'ink']
#
#
# Original Tokens: ['i', 'want', 'to', 'go', 'to', 'music', 'tonight', 'but', 'i', 'lost', 'my', 'voice', '.']
# Stemmed Tokens: ['i', 'want', 'to', 'go', 'to', 'music', 'tonight', 'but', 'i', 'lost', 'my', 'voic', '.']
#
#
# Original Tokens: ['Always', 'somewhere', 'I', 'miss', 'you', 'where', 'I', 'have', 'been']
# Stemmed Tokens: ['alway', 'somewher', 'i', 'miss', 'you', 'where', 'i', 'have', 'been']
#
#
# Original Tokens: ['Do', "n't", 'distrube', 'me']
# Stemmed Tokens: ['do', "n't", 'distrub', 'me']
#
#
# Original Tokens: ['I', 'do', "n't", 'care', ',', 'who', 'are', 'you', 'and', 'what', 'can', 'you', 'do']
# Stemmed Tokens: ['i', 'do', "n't", 'care', ',', 'who', 'are', 'you', 'and', 'what', 'can', 'you', 'do']
#
#
# Original Tokens: ['i', '`', 've', 'been', 'sick', 'for', 'the', 'past', 'few', 'days']
# Stemmed Tokens: ['i', '`', 've', 'been', 'sick', 'for', 'the', 'past', 'few', 'day']
#
#
# Original Tokens: ['I', "'m", 'come', 'back', 'home', ',', 'my', 'past', 'job', ',', 'its', 'really', 'good', 'time', 'for', 'me']
# Stemmed Tokens: ['i', "'m", 'come', 'back', 'home', ',', 'my', 'past', 'job', ',', 'it', 'realli', 'good', 'time', 'for', 'me']
#
#
# Original Tokens: ['I', 'will', 'never', 'fall', 'in', 'love', 'until', 'I', 'found', 'you']
# Stemmed Tokens: ['i', 'will', 'never', 'fall', 'in', 'love', 'until', 'i', 'found', 'you']
#
#
# Original Tokens: ['oh', 'Maya', ',', 'I', '`', 'm', 'so', 'sorry', '!', '!', 'I', 'hope', 'you', 'find', 'her', 'soon', '!', '!']
# Stemmed Tokens: ['oh', 'maya', ',', 'i', '`', 'm', 'so', 'sorri', '!', '!', 'i', 'hope', 'you', 'find', 'her', 'soon', '!', '!']
#
#
# Original Tokens: ['Playing', 'with', 'kids', ',', 'its', 'amazing']
# Stemmed Tokens: ['play', 'with', 'kid', ',', 'it', 'amaz']
#
#
# Original Tokens: ['is', 'cleaning', 'the', 'house', 'for', 'her', 'family', 'who', 'is', 'comming', 'later', 'today', '..']
# Stemmed Tokens: ['is', 'clean', 'the', 'hous', 'for', 'her', 'famili', 'who', 'is', 'com', 'later', 'today', '..']
#
#
# Original Tokens: ['I', 'tried', 'to', 'shtdown', 'my', 'pc', 'and', 'accenditenly', 'I', 'click', 'in', 'the', 'restart', 'button', '.', 'Its', 'really', 'disgusting']
# Stemmed Tokens: ['i', 'tri', 'to', 'shtdown', 'my', 'pc', 'and', 'accenditenli', 'i', 'click', 'in', 'the', 'restart', 'button', '.', 'it', 'realli', 'disgust']
#
#
# Original Tokens: ['Follow', 'me', ',', 'I', 'will', 'follow', 'you', 'too']
# Stemmed Tokens: ['follow', 'me', ',', 'i', 'will', 'follow', 'you', 'too']
#
#
# Original Tokens: ['Its', 'amazing', 'game', ',', 'I', 'playing', 'everyday']
# Stemmed Tokens: ['it', 'amaz', 'game', ',', 'i', 'play', 'everyday']
#
#
# Original Tokens: ['I', '`', 'm', 'sorry', '.']
# Stemmed Tokens: ['i', '`', 'm', 'sorri', '.']
#
#
# Original Tokens: ['I', "'m", 'in', 'the', 'village', 'now', 'and', 'there', 'hardly', 'found', 'internate', ',', 'feeling', 'gloomy']
# Stemmed Tokens: ['i', "'m", 'in', 'the', 'villag', 'now', 'and', 'there', 'hardli', 'found', 'intern', ',', 'feel', 'gloomi']
#
#
# Original Tokens: ['juss', 'came', 'back', 'from', 'Barisal']
# Stemmed Tokens: ['juss', 'came', 'back', 'from', 'baris']
#
#
# Original Tokens: ['Went', 'to', 'sleep', 'and', 'there', 'is', 'a', 'power', 'cut', 'in', 'the', 'village', '.']
# Stemmed Tokens: ['went', 'to', 'sleep', 'and', 'there', 'is', 'a', 'power', 'cut', 'in', 'the', 'villag', '.']
#
#
# Original Tokens: ['How', 'looks', 'like', 'our', 'company', 'new', 'logo', '?']
# Stemmed Tokens: ['how', 'look', 'like', 'our', 'compani', 'new', 'logo', '?']
#
#
# Original Tokens: ['I', 'buy', 'Sophie', "'s", 'world', 'book', ',', 'I', "'m", 'really', 'so', 'happy']
# Stemmed Tokens: ['i', 'buy', 'sophi', "'s", 'world', 'book', ',', 'i', "'m", 'realli', 'so', 'happi']
#
#
# Original Tokens: ['If', 'it', 'is', 'any', 'consolation', 'I', 'got', 'my', 'BMI', 'tested', 'hahaha', 'it', 'says', 'I', 'am', 'obesed', 'well', 'so', 'much', 'for', 'being', 'unhappy', 'for', 'about', '10', 'minutes', '.']
# Stemmed Tokens: ['if', 'it', 'is', 'ani', 'consol', 'i', 'got', 'my', 'bmi', 'test', 'hahaha', 'it', 'say', 'i', 'am', 'obes', 'well', 'so', 'much', 'for', 'be', 'unhappi', 'for', 'about', '10', 'minut', '.']
#
#
# Original Tokens: ['That', '`', 's', 'very', 'funny', '.', 'Cute', 'kids', '.']
# Stemmed Tokens: ['that', '`', 's', 'veri', 'funni', '.', 'cute', 'kid', '.']
#
#
# Original Tokens: ['Ahhh', ',', 'I', 'slept', 'through', 'the', 'game', '.', 'I', '`', 'm', 'gon', 'na', 'try', 'my', 'best', 'to', 'watch', 'tomorrow', 'though', '.', 'I', 'hope', 'we', 'play', 'Army', '.']
# Stemmed Tokens: ['ahhh', ',', 'i', 'slept', 'through', 'the', 'game', '.', 'i', '`', 'm', 'gon', 'na', 'tri', 'my', 'best', 'to', 'watch', 'tomorrow', 'though', '.', 'i', 'hope', 'we', 'play', 'armi', '.']
#
#
# Original Tokens: ['My', 'semester', 'final', 'exam', 'is', 'complete', '.', 'Hurray', '!', '!', '!']
# Stemmed Tokens: ['my', 'semest', 'final', 'exam', 'is', 'complet', '.', 'hurray', '!', '!', '!']
#
#
# Original Tokens: ['Born', 'and', 'raised', 'in', 'NYC', 'and', 'living', 'in', 'Texas', 'for', 'the', 'past', '10', 'years', '!', 'I', 'still', 'miss', 'NY']
# Stemmed Tokens: ['born', 'and', 'rais', 'in', 'nyc', 'and', 'live', 'in', 'texa', 'for', 'the', 'past', '10', 'year', '!', 'i', 'still', 'miss', 'ny']
#
#
# Original Tokens: ['just', 'in', 'case', 'you', 'wonder', ',', 'we', 'are', 'really', 'busy', 'today', 'and', 'this', 'coming', 'with', 'with', 'adding', 'tons', 'of', 'new', 'blogs', 'and', 'updates', 'stay', 'tuned']
# Stemmed Tokens: ['just', 'in', 'case', 'you', 'wonder', ',', 'we', 'are', 'realli', 'busi', 'today', 'and', 'thi', 'come', 'with', 'with', 'ad', 'ton', 'of', 'new', 'blog', 'and', 'updat', 'stay', 'tune']
#
#
# Original Tokens: ['i', '`', 'm', 'soooooo', 'sleeeeepy', '!', '!', '!', 'the', 'last', 'day', 'o', '`', 'school', 'was', 'today', '....', 'sniffle', '....']
# Stemmed Tokens: ['i', '`', 'm', 'soooooo', 'sleeeeepi', '!', '!', '!', 'the', 'last', 'day', 'o', '`', 'school', 'wa', 'today', '....', 'sniffl', '....']
#
#
# Original Tokens: ['romance', 'zero', 'is', 'funny']
# Stemmed Tokens: ['romanc', 'zero', 'is', 'funni']
#
#
# Original Tokens: ['Car', 'not', 'happy', ',', 'big', 'big', 'dent', 'in', 'boot', '!', 'Hoping', 'theyre', 'not', 'going', 'to', 'write', 'it', 'off', ',', 'crossing', 'fingers', 'and', 'waiting']
# Stemmed Tokens: ['car', 'not', 'happi', ',', 'big', 'big', 'dent', 'in', 'boot', '!', 'hope', 'theyr', 'not', 'go', 'to', 'write', 'it', 'off', ',', 'cross', 'finger', 'and', 'wait']
#
#
# Original Tokens: ['Yor', 'are', 'so', 'unromantic']
# Stemmed Tokens: ['yor', 'are', 'so', 'unromant']
#
#
# Original Tokens: ['MAYDAY', '?', '!']
# Stemmed Tokens: ['mayday', '?', '!']
#
#
# Original Tokens: ['I', '`', 'd', 'rather', 'do', 'the', 'early', 'run', '..', 'but', 'I', 'am', 'a', 'morning', 'runner']
# Stemmed Tokens: ['i', '`', 'd', 'rather', 'do', 'the', 'earli', 'run', '..', 'but', 'i', 'am', 'a', 'morn', 'runner']
#
#
# Original Tokens: ['I', 'love', 'to', '!', 'But', 'I', '`', 'm', 'only', 'available', 'from', '5pm', '.', 'and', 'where', 'dear', '?']
# Stemmed Tokens: ['i', 'love', 'to', '!', 'but', 'i', '`', 'm', 'onli', 'avail', 'from', '5pm', '.', 'and', 'where', 'dear', '?']
#
#
# Original Tokens: ['The', 'girl', 'in', 'the', 'hair', 'salon', 'asked', 'me', "'Shall", 'I', 'trim', 'your', 'eyebrows', '!', "'", 'How', 'old', 'do', 'I', 'feel', '?']
# Stemmed Tokens: ['the', 'girl', 'in', 'the', 'hair', 'salon', 'ask', 'me', "'shall", 'i', 'trim', 'your', 'eyebrow', '!', "'", 'how', 'old', 'do', 'i', 'feel', '?']
#
#
# Original Tokens: ['i', 'talk', 'to', 'you']
# Stemmed Tokens: ['i', 'talk', 'to', 'you']
#
#
# Original Tokens: ['Grabbing', 'coffee', 'from', 'then', 'making', 'mom', 'breakfast']
# Stemmed Tokens: ['grab', 'coffe', 'from', 'then', 'make', 'mom', 'breakfast']
#
#
# Original Tokens: ['im', 'thinking', 'that', 'im', 'going', 'to', 'have', 'fun', 'tonight', '....', 'and', 'maybe', 'some', 'changes', 'are', 'coming']
# Stemmed Tokens: ['im', 'think', 'that', 'im', 'go', 'to', 'have', 'fun', 'tonight', '....', 'and', 'mayb', 'some', 'chang', 'are', 'come']
#
#
# Original Tokens: ['thanks', '.', 'before', 'the', 'major', 'chop', '.']
# Stemmed Tokens: ['thank', '.', 'befor', 'the', 'major', 'chop', '.']
#
#
# Original Tokens: ['Haha', 'I', 'know', ',', 'I', 'cant', 'handle', 'the', 'fame', '!', 'and', 'thank', 'you', '!']
# Stemmed Tokens: ['haha', 'i', 'know', ',', 'i', 'cant', 'handl', 'the', 'fame', '!', 'and', 'thank', 'you', '!']
#
#
# Original Tokens: ['just', 'got', 'up', 'and', 'updated', 'my', 'ipod']
# Stemmed Tokens: ['just', 'got', 'up', 'and', 'updat', 'my', 'ipod']
#
#
# Original Tokens: ['I', 'still', 'loving', 'you', ',', 'you', 'are', 'my', 'love']
# Stemmed Tokens: ['i', 'still', 'love', 'you', ',', 'you', 'are', 'my', 'love']
#
#
# Original Tokens: ['Lets', 'go', ',', 'its', 'time', 'to', 'play', 'cricket', 'match']
# Stemmed Tokens: ['let', 'go', ',', 'it', 'time', 'to', 'play', 'cricket', 'match']
#
#
# Original Tokens: ['Hey', 'everyone', ',', 'do', 'you', 'watch', 'cricket', 'match', 'between', 'eng', 'vs', 'aus', 'yesterday']
# Stemmed Tokens: ['hey', 'everyon', ',', 'do', 'you', 'watch', 'cricket', 'match', 'between', 'eng', 'vs', 'au', 'yesterday']
#
#
# Original Tokens: ['Australia', 'cricket', 'team', 'I', 'love', 'you']
# Stemmed Tokens: ['australia', 'cricket', 'team', 'i', 'love', 'you']
#
#
# Original Tokens: ['which', 'means', 'you', '`', 're', 'just', 'going', 'to', 'have', 'to', 'come', 'back', 'to', 'vancouver', 'and', 'have', 'it', 'our', 'way', '!', 'hahah']
# Stemmed Tokens: ['which', 'mean', 'you', '`', 're', 'just', 'go', 'to', 'have', 'to', 'come', 'back', 'to', 'vancouv', 'and', 'have', 'it', 'our', 'way', '!', 'hahah']
#
#
# Original Tokens: ['Feeling', 'smooth', 'like', 'chrome']
# Stemmed Tokens: ['feel', 'smooth', 'like', 'chrome']
#
#
# Original Tokens: ['feeling', 'gloomy']
# Stemmed Tokens: ['feel', 'gloomi']
#
#
# Original Tokens: ['Today', 'we', 'will', 'go', 'a', 'concert']
# Stemmed Tokens: ['today', 'we', 'will', 'go', 'a', 'concert']
#
#
# Original Tokens: ['i', 'need', 'coffee', 'too', '.']
# Stemmed Tokens: ['i', 'need', 'coffe', 'too', '.']
#
#
# Original Tokens: ['Sounds', 'like', 'me']
# Stemmed Tokens: ['sound', 'like', 'me']
#
#
# Original Tokens: ['Bad', 'day', 'The', 'day', 'you', 'realize', 'what', 'mess', 'you', '`', 've', 'put', 'me', 'through', 'will', 'be', 'one', 'of', 'the', 'happiest', 'days', 'of', 'my', 'life', '...']
# Stemmed Tokens: ['bad', 'day', 'the', 'day', 'you', 'realiz', 'what', 'mess', 'you', '`', 've', 'put', 'me', 'through', 'will', 'be', 'one', 'of', 'the', 'happiest', 'day', 'of', 'my', 'life', '...']
#
#
# Original Tokens: ['Walking', 'to', 'class', '.', 'I', 'hate', 'not', 'having', 'a', 'bike', '....', 'especially', 'mine', '.']
# Stemmed Tokens: ['walk', 'to', 'class', '.', 'i', 'hate', 'not', 'have', 'a', 'bike', '....', 'especi', 'mine', '.']
#
#
# Original Tokens: ['I', "'m", 'start', 'learning', 'machine', 'learning']
# Stemmed Tokens: ['i', "'m", 'start', 'learn', 'machin', 'learn']
#
#
# Original Tokens: ['failed', 'inspection', '.']
# Stemmed Tokens: ['fail', 'inspect', '.']
#
#
# Original Tokens: ['Lets', 'sing', 'a', 'song']
# Stemmed Tokens: ['let', 'sing', 'a', 'song']
#
#
# Original Tokens: ['happy', 'father', '`', 's', 'day', 'to', 'all', 'the', 'father', 'in', 'the', 'world', '.']
# Stemmed Tokens: ['happi', 'father', '`', 's', 'day', 'to', 'all', 'the', 'father', 'in', 'the', 'world', '.']
#
#
# Original Tokens: ['Today', ',', 'my', 'semester', 'final', 'exam', 'was', 'really', 'great']
# Stemmed Tokens: ['today', ',', 'my', 'semest', 'final', 'exam', 'wa', 'realli', 'great']
#
#
# Original Tokens: ['Really', 'great', 'day']
# Stemmed Tokens: ['realli', 'great', 'day']
#
#
# Original Tokens: ['The', 'exception', 'for', 'a', 'short', 'dude']
# Stemmed Tokens: ['the', 'except', 'for', 'a', 'short', 'dude']
#
#
# Original Tokens: ['Congratulation', 'for', 'your', 'achievement']
# Stemmed Tokens: ['congratul', 'for', 'your', 'achiev']
#
#
# Original Tokens: ['If', 'you', 'followed', 'us', 'recently', ',', 'PLEASE', 'dont', 'be', 'offended', 'that', 'we', 'haven', '`', 't', 'followed', 'back', '.', 'We', 'hit', 'our', 'limit', '.']
# Stemmed Tokens: ['if', 'you', 'follow', 'us', 'recent', ',', 'pleas', 'dont', 'be', 'offend', 'that', 'we', 'haven', '`', 't', 'follow', 'back', '.', 'we', 'hit', 'our', 'limit', '.']
#
#
# Original Tokens: ['Yes', 'i', 'work', '9', 'to', '5']
# Stemmed Tokens: ['ye', 'i', 'work', '9', 'to', '5']
#
#
# Original Tokens: ['Hmmm', ',', 'maybe', 'that', '`', 's', 'what', 'they', 'meant', '.']
# Stemmed Tokens: ['hmmm', ',', 'mayb', 'that', '`', 's', 'what', 'they', 'meant', '.']
#
#
# Original Tokens: ['Done', 'at', 'the', 'spa', 'now', 'meeting', 'vic', 'for', 'some', 'late', 'lunch', '!']
# Stemmed Tokens: ['done', 'at', 'the', 'spa', 'now', 'meet', 'vic', 'for', 'some', 'late', 'lunch', '!']
#
#
# Original Tokens: ['Happy', 'monday', 'up', 'and', 'about', 'going', 'to', 'tavares', 'today', '.', 'Hope', 'everyone', 'has', 'a', 'blessed', 'day', '!']
# Stemmed Tokens: ['happi', 'monday', 'up', 'and', 'about', 'go', 'to', 'tavar', 'today', '.', 'hope', 'everyon', 'ha', 'a', 'bless', 'day', '!']
#
#
# Original Tokens: ['Always', 'have', 'wanted', 'to', 'go', 'to', 'university']
# Stemmed Tokens: ['alway', 'have', 'want', 'to', 'go', 'to', 'univers']
#
#
# Original Tokens: ['Thanks']
# Stemmed Tokens: ['thank']
#
#
# Original Tokens: ['Really', 'great', 'football', 'match']
# Stemmed Tokens: ['realli', 'great', 'footbal', 'match']
#
#
# Original Tokens: ['that', '`', 's', 'why', 'I', 'need', 'to', 'be', 'there']
# Stemmed Tokens: ['that', '`', 's', 'whi', 'i', 'need', 'to', 'be', 'there']
#
#
# Original Tokens: ['Okay', 'so', 'I', '`', 'm', 'dedicating', 'my', '300th', 'tweet', 'to', 'the', 'fact', 'that', 'I', '`', 'm', 'going', 'to', 'the', 'Apple', 'store', 'because', 'there', 'is', 'a', 'HUGE', 'crack', 'on', 'the', 'glass', 'screen', '!']
# Stemmed Tokens: ['okay', 'so', 'i', '`', 'm', 'dedic', 'my', '300th', 'tweet', 'to', 'the', 'fact', 'that', 'i', '`', 'm', 'go', 'to', 'the', 'appl', 'store', 'becaus', 'there', 'is', 'a', 'huge', 'crack', 'on', 'the', 'glass', 'screen', '!']
#
#
# Original Tokens: ['If', 'only', 'we', 'could', 'ever', 'actually', 'be', 'allowed', 'to', 'stay', 'here', 'and', 'do', 'that']
# Stemmed Tokens: ['if', 'onli', 'we', 'could', 'ever', 'actual', 'be', 'allow', 'to', 'stay', 'here', 'and', 'do', 'that']
#
#
# Original Tokens: ['Let', 'me', 'know', 'how', 'that', 'turns', 'out', '!', '!']
# Stemmed Tokens: ['let', 'me', 'know', 'how', 'that', 'turn', 'out', '!', '!']
#
#
# Original Tokens: ['was', 'that', 'sass', 'I', 'detect', '?', 'As', 'long', 'as', 'it', 'isn', '`', 't', 'back', 'sass', '!', 'Haha']
# Stemmed Tokens: ['wa', 'that', 'sass', 'i', 'detect', '?', 'as', 'long', 'as', 'it', 'isn', '`', 't', 'back', 'sass', '!', 'haha']
#
#
# Original Tokens: ['yeah', 'I', 'was', 'thinking', 'about', 'that', ',', 'ahaha']
# Stemmed Tokens: ['yeah', 'i', 'wa', 'think', 'about', 'that', ',', 'ahaha']
#
#
# Original Tokens: ['Today', 'is', 'our', 'EEE', 'day']
# Stemmed Tokens: ['today', 'is', 'our', 'eee', 'day']
#
#
# Original Tokens: ['I', '`', 'm', 'not', 'sleeping', 'at', 'all', 'until', 'accepts', 'my', 'appology']
# Stemmed Tokens: ['i', '`', 'm', 'not', 'sleep', 'at', 'all', 'until', 'accept', 'my', 'appolog']
#
#
# Original Tokens: ['I', "'m", 'studying', 'in', 'psychology']
# Stemmed Tokens: ['i', "'m", 'studi', 'in', 'psycholog']
#
#
# Original Tokens: ['I', 'live', 'for', 'pain', ',', 'bring', 'it', 'on']
# Stemmed Tokens: ['i', 'live', 'for', 'pain', ',', 'bring', 'it', 'on']
#
#
# Original Tokens: ['okay', ',', 'i', '`', 'm', 'out', 'for', 'a', 'while', 'back', 'later', '!']
# Stemmed Tokens: ['okay', ',', 'i', '`', 'm', 'out', 'for', 'a', 'while', 'back', 'later', '!']
#
#
# Original Tokens: ['We', 'visited', 'worlds', 'longest', 'sea', 'beach', ',', 'Its', 'really', 'amazing', 'time', 'for', 'us']
# Stemmed Tokens: ['we', 'visit', 'world', 'longest', 'sea', 'beach', ',', 'it', 'realli', 'amaz', 'time', 'for', 'us']
#
#
# Original Tokens: ['almost', 'died', '.', 'Laptop', 'screen', 'was', 'set', 'to', '100', '%', 'brightness', 'after', 'I', 'reinstalled', 'Windows', 'Vista', '.']
# Stemmed Tokens: ['almost', 'die', '.', 'laptop', 'screen', 'wa', 'set', 'to', '100', '%', 'bright', 'after', 'i', 'reinstal', 'window', 'vista', '.']
#
#
# Original Tokens: ['Waiting', 'for', 'tish', 'to', 'get', 'off', '.', 'Got', 'to', 'drive', 'my', 'moms', 'CRV', 'to', 'pick', 'her', 'up', 'all', 'my', 'myself', 'and', 'duckie', '.', 'First', 'time']
# Stemmed Tokens: ['wait', 'for', 'tish', 'to', 'get', 'off', '.', 'got', 'to', 'drive', 'my', 'mom', 'crv', 'to', 'pick', 'her', 'up', 'all', 'my', 'myself', 'and', 'ducki', '.', 'first', 'time']
#
#
# Original Tokens: ['your', 'attitude', 'looks', 'like', 'autistics', 'child']
# Stemmed Tokens: ['your', 'attitud', 'look', 'like', 'autist', 'child']
#
#
# Original Tokens: ['going', 'to', 'shower', 'because', 'i', 'don', '`', 't', 'want', 'to', 'smell', 'at', 'school', 'tomorrow']
# Stemmed Tokens: ['go', 'to', 'shower', 'becaus', 'i', 'don', '`', 't', 'want', 'to', 'smell', 'at', 'school', 'tomorrow']
#
#
# Original Tokens: ['Do', 'you', 'know', 'sign', 'languages']
# Stemmed Tokens: ['do', 'you', 'know', 'sign', 'languag']
#
#
# Original Tokens: ['Since', 'the', 'demise', 'of', 'Woolworths', 'it', 'isn', '`', 't', 'easy', 'to', 'find', 'reasonably', 'priced', 'pick', 'n', 'mix', 'anywhere']
# Stemmed Tokens: ['sinc', 'the', 'demis', 'of', 'woolworth', 'it', 'isn', '`', 't', 'easi', 'to', 'find', 'reason', 'price', 'pick', 'n', 'mix', 'anywher']
#
#
# Original Tokens: ['may', 'the', 'fourth', 'be', 'with', 'you', '!', 'happy', 'star', 'wars', 'day']
# Stemmed Tokens: ['may', 'the', 'fourth', 'be', 'with', 'you', '!', 'happi', 'star', 'war', 'day']
#
#
# Original Tokens: ['just', 'got', 'home', 'from', 'work']
# Stemmed Tokens: ['just', 'got', 'home', 'from', 'work']
#
#
# Original Tokens: ['Yes', 'it', 'does', '.', 'Please', 'dont', '`', 'go', '.', 'If', 'you', 'die', 'I', 'will', 'cry', '..', 'which', 'normally', 'leads', 'to', 'small', 'animals', 'getting', 'harmed']
# Stemmed Tokens: ['ye', 'it', 'doe', '.', 'pleas', 'dont', '`', 'go', '.', 'if', 'you', 'die', 'i', 'will', 'cri', '..', 'which', 'normal', 'lead', 'to', 'small', 'anim', 'get', 'harm']
#
#
# Original Tokens: ['writing', 'report', 'cards', 'soooo', 'tired', 'but', 'what', 'an', 'amazing', 'day', '.', 'check', 'it', 'out', 'on', 'fb', 'soon', '!']
# Stemmed Tokens: ['write', 'report', 'card', 'soooo', 'tire', 'but', 'what', 'an', 'amaz', 'day', '.', 'check', 'it', 'out', 'on', 'fb', 'soon', '!']
#
#
# Original Tokens: ['it', 'was', 'only', 'once', 'for', 'my', 'big', 'brother']
# Stemmed Tokens: ['it', 'wa', 'onli', 'onc', 'for', 'my', 'big', 'brother']
#
#
# Original Tokens: ['good', 'news', ':', 'finally', 'finished', 'my', 'bachelor', 'degree']
# Stemmed Tokens: ['good', 'news', ':', 'final', 'finish', 'my', 'bachelor', 'degre']
#
#
# Original Tokens: ['Well', 'good', 'morning', 'all', ',', 'What', 'a', 'wonderful', 'day', 'in', 'the', 'neighborhood', 'Thanks', 'for', 'all', 'those', 'that', 'are', 'now', 'following', 'another', '60', 'this', 'morning']
# Stemmed Tokens: ['well', 'good', 'morn', 'all', ',', 'what', 'a', 'wonder', 'day', 'in', 'the', 'neighborhood', 'thank', 'for', 'all', 'those', 'that', 'are', 'now', 'follow', 'anoth', '60', 'thi', 'morn']
#
#
# Original Tokens: ['yesterday', 'I', "'m", 'watch', 'a', 'movie', ',', 'that', '’', 's', 'was', 'really', 'motivated', 'for', 'me']
# Stemmed Tokens: ['yesterday', 'i', "'m", 'watch', 'a', 'movi', ',', 'that', '’', 's', 'wa', 'realli', 'motiv', 'for', 'me']
#
#
# Original Tokens: ['hope', 'he', 'is', 'ok', '!']
# Stemmed Tokens: ['hope', 'he', 'is', 'ok', '!']
#
#
# Original Tokens: ['can', '`', 't', 'school', 'just', 'be', 'done', 'already', '?', 'it', 'hurts', 'too', 'much', '...', 'seeing', 'him', 'every', 'day']
# Stemmed Tokens: ['can', '`', 't', 'school', 'just', 'be', 'done', 'alreadi', '?', 'it', 'hurt', 'too', 'much', '...', 'see', 'him', 'everi', 'day']
#
#
# Original Tokens: ['I', 'waited', ',', 'listening', 'to', 'wind', 'blowing', 'through', 'the', 'tumbleweed', '?', 'Are', 'none', 'of', 'you', 'old', 'enough', 'to', 'know', 'what', 'to', 'do', 'when', 'someone', 'says', "'Crackerack", "'", '?']
# Stemmed Tokens: ['i', 'wait', ',', 'listen', 'to', 'wind', 'blow', 'through', 'the', 'tumblewe', '?', 'are', 'none', 'of', 'you', 'old', 'enough', 'to', 'know', 'what', 'to', 'do', 'when', 'someon', 'say', "'crackerack", "'", '?']
#
#
# Original Tokens: ['Hell', 'Yeah', '!']
# Stemmed Tokens: ['hell', 'yeah', '!']
#
#
# Original Tokens: ['HIM', 'shirt', 'at', 'dinner', '?', 'Do', 'you', 'need', 'to', 'ask', '?', '?', 'Does', 'it', 'actually', 'have', 'Ville', 'on', 'it', '?']
# Stemmed Tokens: ['him', 'shirt', 'at', 'dinner', '?', 'do', 'you', 'need', 'to', 'ask', '?', '?', 'doe', 'it', 'actual', 'have', 'vill', 'on', 'it', '?']
#
#
# Original Tokens: ['i', 'know', '!', '!']
# Stemmed Tokens: ['i', 'know', '!', '!']
#
#
# Original Tokens: ['Smelly', '?', 'Noooo', '.', 'I', 'love', 'alex', 'Vixon']
# Stemmed Tokens: ['smelli', '?', 'noooo', '.', 'i', 'love', 'alex', 'vixon']
#
#
# Original Tokens: ['Went', 'to', 'a', 'party', 'last', 'night', '.', 'GREAT', 'MINDS', 'THINK', 'ALIKE', 'Anyway', ',', 'happy', 'birthday']
# Stemmed Tokens: ['went', 'to', 'a', 'parti', 'last', 'night', '.', 'great', 'mind', 'think', 'alik', 'anyway', ',', 'happi', 'birthday']
#
#
# Original Tokens: ['Happy', 'birthday', '!', 'Just', 'woke', 'up', 'on', 'this', 'side', 'of', 'Earth', ',', 'so', 'wishes', 'are', 'bit', 'late']
# Stemmed Tokens: ['happi', 'birthday', '!', 'just', 'woke', 'up', 'on', 'thi', 'side', 'of', 'earth', ',', 'so', 'wish', 'are', 'bit', 'late']
#
#
# Original Tokens: ['thank', 'you', 'for', 'teaching', 'me', 'values', 'and', 'to', 'be', 'a', 'better', 'person', 'each', 'day', 'I', 'LOVE', 'SO', 'MUCH', ',', 'YOU', '`', 'RE', 'THE', 'BEST', 'MUM', 'IN', 'THE', 'WORLD']
# Stemmed Tokens: ['thank', 'you', 'for', 'teach', 'me', 'valu', 'and', 'to', 'be', 'a', 'better', 'person', 'each', 'day', 'i', 'love', 'so', 'much', ',', 'you', '`', 're', 'the', 'best', 'mum', 'in', 'the', 'world']
#
#
# Original Tokens: ['HAPPY', 'MOTHERS', 'DAY', '.', '!']
# Stemmed Tokens: ['happi', 'mother', 'day', '.', '!']
#
#
# Original Tokens: ['laughs', 'I', '`', 'm', 'glad', 'that', 'you', 'have', 'self', 'confidence', '-', 'it', '`', 's', 'a', 'wonderful', 'trait', 'to', 'have', 'I', '`', 'll', 'applaud', 'extra', 'loud', 'for', 'it', ',', 'okay', '?']
# Stemmed Tokens: ['laugh', 'i', '`', 'm', 'glad', 'that', 'you', 'have', 'self', 'confid', '-', 'it', '`', 's', 'a', 'wonder', 'trait', 'to', 'have', 'i', '`', 'll', 'applaud', 'extra', 'loud', 'for', 'it', ',', 'okay', '?']
#
#
# Original Tokens: ['Thanks']
# Stemmed Tokens: ['thank']
#
#
# Original Tokens: ['twittering', 'after', '2', 'days', '!']
# Stemmed Tokens: ['twitter', 'after', '2', 'day', '!']
#
#
# Original Tokens: ['Getting', 'ready', 'for', 'week', 'Its', 'too', 'nice', 'today', 'to', 'be', 'stuck', 'inside', 'working', '!']
# Stemmed Tokens: ['get', 'readi', 'for', 'week', 'it', 'too', 'nice', 'today', 'to', 'be', 'stuck', 'insid', 'work', '!']
#
#
# Original Tokens: ['I', 'am', 'tres', 'depressed']
# Stemmed Tokens: ['i', 'am', 'tre', 'depress']
#
#
# Original Tokens: ['Felt', 'like', '*', '*', '*', '*', ',', 'behaved', 'like', 'my', 'son', ';', 'ate', 'to', 'compensate', '.', 'Pigged', 'out', 'on', 'home-roasted', 'sugar', 'almonds', '.', 'Painful', 'tum', ',', 'threw', 'up', ',', 'still', 'feel', 'sick', '.']
# Stemmed Tokens: ['felt', 'like', '*', '*', '*', '*', ',', 'behav', 'like', 'my', 'son', ';', 'ate', 'to', 'compens', '.', 'pig', 'out', 'on', 'home-roast', 'sugar', 'almond', '.', 'pain', 'tum', ',', 'threw', 'up', ',', 'still', 'feel', 'sick', '.']
#
#
# Original Tokens: ['Happy', 'Mothers', 'Day', 'people', '.', 'i', 'love', 'my', 'mom', 'a', 'lot', 'still']
# Stemmed Tokens: ['happi', 'mother', 'day', 'peopl', '.', 'i', 'love', 'my', 'mom', 'a', 'lot', 'still']
#
#
# Original Tokens: ['I', '`', 'm', 'sorry', 'to', 'hear', 'that', '.']
# Stemmed Tokens: ['i', '`', 'm', 'sorri', 'to', 'hear', 'that', '.']
#
#
# Original Tokens: ['That', '`', 's', 'awesome', 'dude', ',', 'yay', 'for', 'surprise', 'celebrities', '!', 'I', 'got', 'to', 'meet', 'him', 'a', 'few', 'years', 'ago', ',', 'he', 'was', 'soooo', 'friendly', '.']
# Stemmed Tokens: ['that', '`', 's', 'awesom', 'dude', ',', 'yay', 'for', 'surpris', 'celebr', '!', 'i', 'got', 'to', 'meet', 'him', 'a', 'few', 'year', 'ago', ',', 'he', 'wa', 'soooo', 'friendli', '.']
#
#
# Original Tokens: ['it', 'makes', 'me', 'happy', 'to', 'hear', 'a', 'girl', 'talk', ',', 'or', 'tweet', ',', 'about', 'the', 'nba', '.', 'but', '...', 'could', 'you', 'give', 'my', 'nuggets', 'some', 'love', '?', '!']
# Stemmed Tokens: ['it', 'make', 'me', 'happi', 'to', 'hear', 'a', 'girl', 'talk', ',', 'or', 'tweet', ',', 'about', 'the', 'nba', '.', 'but', '...', 'could', 'you', 'give', 'my', 'nugget', 'some', 'love', '?', '!']
#
#
# Original Tokens: ['Is', 'getting', 'the', 'hang', 'of', 'Twitter', '.']
# Stemmed Tokens: ['is', 'get', 'the', 'hang', 'of', 'twitter', '.']
#
#
# Original Tokens: ['You', 'know', 'your', 'neck', 'is', 'jacked', 'up', 'when', 'you', 'are', 'forced', 'to', 'pay', 'for', 'parking', 'bc', 'you', 'can', '`', 't', 'turn', 'you', 'head', 'to', 'parallel', 'park', 'in', 'the', 'free', 'spaces', '...']
# Stemmed Tokens: ['you', 'know', 'your', 'neck', 'is', 'jack', 'up', 'when', 'you', 'are', 'forc', 'to', 'pay', 'for', 'park', 'bc', 'you', 'can', '`', 't', 'turn', 'you', 'head', 'to', 'parallel', 'park', 'in', 'the', 'free', 'space', '...']
#
#
# Original Tokens: ['I', 'want', 'it', 'BACK', 'NOW', '!']
# Stemmed Tokens: ['i', 'want', 'it', 'back', 'now', '!']
#
#
# Original Tokens: ['Going', 'to', 'miss', 'my', 'roomie', '...', 'We', 'will', 'no', 'longer', 'be', 'roomies', 'starting', 'tomorrow']
# Stemmed Tokens: ['go', 'to', 'miss', 'my', 'roomi', '...', 'we', 'will', 'no', 'longer', 'be', 'roomi', 'start', 'tomorrow']
#
#
# Original Tokens: ['bathing', 'with', 'two', 'little', 'angels', ',', 'Keyla', 'and', 'Janice', '.']
# Stemmed Tokens: ['bath', 'with', 'two', 'littl', 'angel', ',', 'keyla', 'and', 'janic', '.']
#
#
# Original Tokens: ['Yep', ',', 'finished', ',', 'chocked', 'full', 'of', 'spelling', 'and', 'grammatical', 'errors', ',', 'but', 'I', '`', 'm', 'cleaning', 'it', 'up', 'tomorrow', 'and', 'popping', 'it', 'up', 'hehe']
# Stemmed Tokens: ['yep', ',', 'finish', ',', 'chock', 'full', 'of', 'spell', 'and', 'grammat', 'error', ',', 'but', 'i', '`', 'm', 'clean', 'it', 'up', 'tomorrow', 'and', 'pop', 'it', 'up', 'hehe']
#
#
# Original Tokens: ['HAHAHHA', 'lol', 'true', 'that', '!', 'i', 'always', 'remember', 'my', 'BD', 'but', 'i', 'can', 'never', 'remember', 'what', 'date', 'or', 'even', 'day', 'it', 'is']
# Stemmed Tokens: ['hahahha', 'lol', 'true', 'that', '!', 'i', 'alway', 'rememb', 'my', 'bd', 'but', 'i', 'can', 'never', 'rememb', 'what', 'date', 'or', 'even', 'day', 'it', 'is']
#
#
# Original Tokens: ['Family', 'is', 'here', ',', 'hanging', 'with', 'them']
# Stemmed Tokens: ['famili', 'is', 'here', ',', 'hang', 'with', 'them']
#
#
# Original Tokens: ['Watching', 'Ellen', 'Love', 'her', '!', '!', 'then', 'doing', 'the', 'dishes', 'and', 'tanning', '...', 'it', '`', 's', 'gorgeous', 'out', '!']
# Stemmed Tokens: ['watch', 'ellen', 'love', 'her', '!', '!', 'then', 'do', 'the', 'dish', 'and', 'tan', '...', 'it', '`', 's', 'gorgeou', 'out', '!']
#
#
# Original Tokens: ['what', '`', 's', 'goin', 'on', 'hun', '?', 'I', '`', 'm', 'worried', 'about', 'you']
# Stemmed Tokens: ['what', '`', 's', 'goin', 'on', 'hun', '?', 'i', '`', 'm', 'worri', 'about', 'you']
#
#
# Original Tokens: ['Im', 'not', 'bannished', '...', 'but', 'I', 'am', 'at', 'work', 'till', '6']
# Stemmed Tokens: ['im', 'not', 'bannish', '...', 'but', 'i', 'am', 'at', 'work', 'till', '6']
#
#
# Original Tokens: ['Morning', '!', 'If', 'I', 'get', 'to', 'see', 'it', ',', 'I', '`', 'll', 'let', 'you', 'know', '.', 'Right', 'now', ',', 'I', '`', 'm', 'going', 'to', 'go', 'see', 'Wolverine', '.']
# Stemmed Tokens: ['morn', '!', 'if', 'i', 'get', 'to', 'see', 'it', ',', 'i', '`', 'll', 'let', 'you', 'know', '.', 'right', 'now', ',', 'i', '`', 'm', 'go', 'to', 'go', 'see', 'wolverin', '.']
#
#
# Original Tokens: ['Grabbing', 'coffee', 'from', 'then', 'making', 'mom', 'breakfast']
# Stemmed Tokens: ['grab', 'coffe', 'from', 'then', 'make', 'mom', 'breakfast']
#
#
# Original Tokens: ['im', 'thinking', 'that', 'im', 'going', 'to', 'have', 'fun', 'tonight', '....', 'and', 'maybe', 'some', 'changes', 'are', 'coming']
# Stemmed Tokens: ['im', 'think', 'that', 'im', 'go', 'to', 'have', 'fun', 'tonight', '....', 'and', 'mayb', 'some', 'chang', 'are', 'come']
#
#
# Original Tokens: ['Grabbing', 'coffee', 'from', 'then', 'making', 'mom', 'breakfast']
# Stemmed Tokens: ['grab', 'coffe', 'from', 'then', 'make', 'mom', 'breakfast']
#
#
# Original Tokens: ['im', 'thinking', 'that', 'im', 'going', 'to', 'have', 'fun', 'tonight', '....', 'and', 'maybe', 'some', 'changes', 'are', 'coming']
# Stemmed Tokens: ['im', 'think', 'that', 'im', 'go', 'to', 'have', 'fun', 'tonight', '....', 'and', 'mayb', 'some', 'chang', 'are', 'come']
#
#
# Original Tokens: ['thanks', '.', 'before', 'the', 'major', 'chop', '.']
# Stemmed Tokens: ['thank', '.', 'befor', 'the', 'major', 'chop', '.']
#
#
# Original Tokens: ['Haha', 'I', 'know', ',', 'I', 'cant', 'handle', 'the', 'fame', '!', 'and', 'thank', 'you', '!']
# Stemmed Tokens: ['haha', 'i', 'know', ',', 'i', 'cant', 'handl', 'the', 'fame', '!', 'and', 'thank', 'you', '!']
#
#
# Original Tokens: ['just', 'got', 'up', 'and', 'updated', 'my', 'ipod']
# Stemmed Tokens: ['just', 'got', 'up', 'and', 'updat', 'my', 'ipod']
#
#
# Original Tokens: ['yes', '!', 'sober', 'HAHAHA', 'tanghaling', 'tapat', 'dude', '!', 'haha', 'WILD', '.', 'i', 'don', '`', 't', 'knowwww', 'plan', 'plan', 'before', 'you', 'go', 'to', 'US', '!']
# Stemmed Tokens: ['ye', '!', 'sober', 'hahaha', 'tanghal', 'tapat', 'dude', '!', 'haha', 'wild', '.', 'i', 'don', '`', 't', 'knowwww', 'plan', 'plan', 'befor', 'you', 'go', 'to', 'us', '!']
#
#
# Original Tokens: ['We', 'never', 'miss', 'ICarly', '-', 'my', 'son', 'has', 'a', 'huge', 'crush', 'on', 'Miranda']
# Stemmed Tokens: ['we', 'never', 'miss', 'icarli', '-', 'my', 'son', 'ha', 'a', 'huge', 'crush', 'on', 'miranda']
#
#
# Original Tokens: ['Saw', 'James', 'carville', 'in', 'the', 'store', 'today', '.', 'His', 'head', 'is', 'really', 'that', 'bald']
# Stemmed Tokens: ['saw', 'jame', 'carvil', 'in', 'the', 'store', 'today', '.', 'hi', 'head', 'is', 'realli', 'that', 'bald']
#
#
# Original Tokens: ['I', 'love', 'blue', 'and', 'programming']
# Stemmed Tokens: ['i', 'love', 'blue', 'and', 'program']
#
#
# Original Tokens: ['which', 'means', 'you', '`', 're', 'just', 'going', 'to', 'have', 'to', 'come', 'back', 'to', 'vancouver', 'and', 'have', 'it', 'our', 'way', '!', 'hahah']
# Stemmed Tokens: ['which', 'mean', 'you', '`', 're', 'just', 'go', 'to', 'have', 'to', 'come', 'back', 'to', 'vancouv', 'and', 'have', 'it', 'our', 'way', '!', 'hahah']
#
#
# Original Tokens: ['Feeling', 'smooth', 'like', 'chrome']
# Stemmed Tokens: ['feel', 'smooth', 'like', 'chrome']
#
#
# Original Tokens: ['Errors', 'are', 'red', 'but', 'my', 'life', 'is', 'looks', 'like', 'blue', 'film']
# Stemmed Tokens: ['error', 'are', 'red', 'but', 'my', 'life', 'is', 'look', 'like', 'blue', 'film']
#
#
# Original Tokens: ['downloading', 'songs', 'while', 'trying', 'to', 'sneak', 'a', 'lil', 'homework', 'in', 'too', ',', 'which', 'should', 'be', 'my', 'main', 'priority', 'not', 'songs', 'lol']
# Stemmed Tokens: ['download', 'song', 'while', 'tri', 'to', 'sneak', 'a', 'lil', 'homework', 'in', 'too', ',', 'which', 'should', 'be', 'my', 'main', 'prioriti', 'not', 'song', 'lol']
#
#
# Original Tokens: ['Errors', 'are', 'red', 'but', 'my', 'life', 'is', 'blue', ',', 'I', 'love', 'rose', 'and', 'your', 'lips', 'baby']
# Stemmed Tokens: ['error', 'are', 'red', 'but', 'my', 'life', 'is', 'blue', ',', 'i', 'love', 'rose', 'and', 'your', 'lip', 'babi']
#
#
# Original Tokens: ['Sounds', 'like', 'me']
# Stemmed Tokens: ['sound', 'like', 'me']
#
#
# Original Tokens: ['Bad', 'day', 'The', 'day', 'you', 'realize', 'what', 'mess', 'you', '`', 've', 'put', 'me', 'through', 'will', 'be', 'one', 'of', 'the', 'happiest', 'days', 'of', 'my', 'life', '...']
# ...
# Stemmed Tokens: ['discov', 'and', 'are', 'share', 'on', 'g', 'reader', 'with', 'me', 'and', 'didn', '`', 't', 'even', 'know', 'it', '.', 'sigh', '....', 'i', '`', 'm', 'such', 'a', 'g', 'reader', 'newb', '.']
#
#
# Original Tokens: ['is', 'chilled', 'out', 'tonite', ',', 'so', 'can', 'not', 'spew', 'venom', 'or', 'write', 'funny', '.', 'Seems', 'like', 'these', 'are', 'the', 'only', '2', 'styles', 'she', 'has']
# Stemmed Tokens: ['is', 'chill', 'out', 'tonit', ',', 'so', 'can', 'not', 'spew', 'venom', 'or', 'write', 'funni', '.', 'seem', 'like', 'these', 'are', 'the', 'onli', '2', 'style', 'she', 'ha']
#
#
# Original Tokens: ['If', 'u', 'do', ',', 'please', 'pray', '4', 'me', '.', 'Lord', 'knows', 'I', 'need', 'it', '.']
# Stemmed Tokens: ['if', 'u', 'do', ',', 'pleas', 'pray', '4', 'me', '.', 'lord', 'know', 'i', 'need', 'it', '.']
#
#
# Original Tokens: ['aaaaaw', 'i', 'want', 'to', 'live', 'in', 'the', 'USA']
# Stemmed Tokens: ['aaaaaw', 'i', 'want', 'to', 'live', 'in', 'the', 'usa']
#
#
# Original Tokens: ['Morning', 'tweeple']
# Stemmed Tokens: ['morn', 'tweepl']
#
#
# Original Tokens: ['Hey', ',', 'I', 'didn', '`', 't', 'get', 'any', '!', '!', '!']
# Stemmed Tokens: ['hey', ',', 'i', 'didn', '`', 't', 'get', 'ani', '!', '!', '!']
#
#
# Original Tokens: ['Now', 'you', 'only', 'have', '2', 'hours', 'to', 'sleep', '...', '-', 'Rest', 'if', 'you', 'need', 'it', '.']
# Stemmed Tokens: ['now', 'you', 'onli', 'have', '2', 'hour', 'to', 'sleep', '...', '-', 'rest', 'if', 'you', 'need', 'it', '.']
#
#
# Original Tokens: ['That', 'makes', 'my', 'day', 'so', 'much', 'better', ',', 'it', '`', 's', 'been', 'a', 'rough', 'one', '.', 'Did', 'I', 'mention', 'I', 'love', 'the', 'new', 'photo', '!']
# Stemmed Tokens: ['that', 'make', 'my', 'day', 'so', 'much', 'better', ',', 'it', '`', 's', 'been', 'a', 'rough', 'one', '.', 'did', 'i', 'mention', 'i', 'love', 'the', 'new', 'photo', '!']
#
#
# Original Tokens: ['I', 'don', '`', 't', 'want', 'to', 'sit', 'at', 'home', 'on', 'prom', 'night', '.', 'Someone', 'hang', 'out', 'with', 'me']
# Stemmed Tokens: ['i', 'don', '`', 't', 'want', 'to', 'sit', 'at', 'home', 'on', 'prom', 'night', '.', 'someon', 'hang', 'out', 'with', 'me']
#
#
# Original Tokens: ['Is', 'heading', 'home', 'from', 'foot', 'surgery', 'and', 'wishing', 'she', 'had', 'a', 'boyfriend', 'to', 'come', 'over', 'and', 'cuddle', 'with']
# Stemmed Tokens: ['is', 'head', 'home', 'from', 'foot', 'surgeri', 'and', 'wish', 'she', 'had', 'a', 'boyfriend', 'to', 'come', 'over', 'and', 'cuddl', 'with']
#
#
# Original Tokens: ['concert', 'tonight', 'chackin', 'out', 'and', 'not', 'coming', 'tomorrow', '!']
# Stemmed Tokens: ['concert', 'tonight', 'chackin', 'out', 'and', 'not', 'come', 'tomorrow', '!']
#
#
# Original Tokens: ['what', 'happened', '?', 'I', 'thought', 'you', 'were', 'coming', 'back', 'today', '....']
# Stemmed Tokens: ['what', 'happen', '?', 'i', 'thought', 'you', 'were', 'come', 'back', 'today', '....']
#
#
# Original Tokens: ['lol', 'dammit', 'well', 'then', 'next', 'time', 'then']
# Stemmed Tokens: ['lol', 'dammit', 'well', 'then', 'next', 'time', 'then']
#
#
# Original Tokens: ['lol', '.', 'just', 'don', '`', 't', 'ever', 'forget', 'me']
# Stemmed Tokens: ['lol', '.', 'just', 'don', '`', 't', 'ever', 'forget', 'me']
#
#
# Original Tokens: ['Still', 'jealous']
# Stemmed Tokens: ['still', 'jealou']
#
#
# Original Tokens: ['Me', 'at', 'Forever', '21', 'Ethan', 'couldn', '`', 't', 'be', 'there']
# Stemmed Tokens: ['me', 'at', 'forev', '21', 'ethan', 'couldn', '`', 't', 'be', 'there']
#
#
# Original Tokens: ['NOW', 'IM', 'SAD', 'BUT', 'IM', 'NOT', 'GIVING', 'IN', 'FIRST', '..', 'I', 'DIDNT', 'DO', 'NOTHING', '!', '!', '!', '!', ':', '*', '*', '-', '(']
# Stemmed Tokens: ['now', 'im', 'sad', 'but', 'im', 'not', 'give', 'in', 'first', '..', 'i', 'didnt', 'do', 'noth', '!', '!', '!', '!', ':', '*', '*', '-', '(']
#
#
# Original Tokens: ['this', 'week', 'of', 'mine', 'was', 'not', 'easy', '!', 'but', 'finally', 'it', '`', 's', 'over', '!', '(', ':']
# Stemmed Tokens: ['thi', 'week', 'of', 'mine', 'wa', 'not', 'easi', '!', 'but', 'final', 'it', '`', 's', 'over', '!', '(', ':']
#
#
# Original Tokens: ['Wow', 'what', 'a', 'beautiful', 'picture', '...', 'and', 'by', 'the', 'way', '....', 'I', 'am', 'straight', '....', 'just', 'wanted', 'to', 'let', 'you', 'know', '!', '!', '!', 'Bella']
# Stemmed Tokens: ['wow', 'what', 'a', 'beauti', 'pictur', '...', 'and', 'by', 'the', 'way', '....', 'i', 'am', 'straight', '....', 'just', 'want', 'to', 'let', 'you', 'know', '!', '!', '!', 'bella']
#
#
# Original Tokens: ['In', 'Arch', '.', 'Drawing', '.', 'Checking', 'out', 'MVCC', '`', 's', 'CAD', 'degree', '.', 'Looks', 'good', 'to', 'me']
# Stemmed Tokens: ['in', 'arch', '.', 'draw', '.', 'check', 'out', 'mvcc', '`', 's', 'cad', 'degre', '.', 'look', 'good', 'to', 'me']
#
#
# Original Tokens: ["'there", 'are', 'people', 'and', 'then', 'there', 'are', 'pencils', "'", 'some', 'are', 'sharp', ',', 'some', 'are', 'not', 'and', 'some', 'can', 'be', 'sharpened', 'my', 'pencil', 'philosophy', '.....']
# Stemmed Tokens: ["'there", 'are', 'peopl', 'and', 'then', 'there', 'are', 'pencil', "'", 'some', 'are', 'sharp', ',', 'some', 'are', 'not', 'and', 'some', 'can', 'be', 'sharpen', 'my', 'pencil', 'philosophi', '.....']
#
#
# Original Tokens: ['just', 'about', 'to', 'go', 'home', '.', 'I', '`', 'm', 'usually', '`', 'mr.', 'positive', '`', 'but', 'this', 'has', 'been', 'one', 'of', 'those', 'daze', '.', 'well', ',', '15', 'mins', 'until', 'tomorrow', '!']
# Stemmed Tokens: ['just', 'about', 'to', 'go', 'home', '.', 'i', '`', 'm', 'usual', '`', 'mr.', 'posit', '`', 'but', 'thi', 'ha', 'been', 'one', 'of', 'those', 'daze', '.', 'well', ',', '15', 'min', 'until', 'tomorrow', '!']
#
#
# Original Tokens: ['but', 'you', 'always', 'have', 'lee', '.', 'Let', '`', 's', 'go', 'to', 'Paris']
# Stemmed Tokens: ['but', 'you', 'alway', 'have', 'lee', '.', 'let', '`', 's', 'go', 'to', 'pari']
#
#
# Original Tokens: ['you', 'know', 'you', 'want', 'to', 'come', 'keep', 'me', 'company', 'whilst', 'mum', '`', 's', 'at', 'her', 'friends', 'for', 'the', 'night', 'it', '`', 's', 'such', 'a', 'nice', 'evening', '!']
# Stemmed Tokens: ['you', 'know', 'you', 'want', 'to', 'come', 'keep', 'me', 'compani', 'whilst', 'mum', '`', 's', 'at', 'her', 'friend', 'for', 'the', 'night', 'it', '`', 's', 'such', 'a', 'nice', 'even', '!']
#
#
# Original Tokens: ['cooking', 'with', 'my', 'dad', 'having', 'lots', 'of', 'fun', 'in', 'the', 'kitchen', 'together']
# Stemmed Tokens: ['cook', 'with', 'my', 'dad', 'have', 'lot', 'of', 'fun', 'in', 'the', 'kitchen', 'togeth']
#
#
# Original Tokens: ['Bouncing', 'Rush', 'makes', 'me', 'feel', 'nauseous']
# Stemmed Tokens: ['bounc', 'rush', 'make', 'me', 'feel', 'nauseou']
#
#
# Original Tokens: ['Off', 'to', 'Woolsery', 'this', 'morning', 'to', '(', 'hopefully', ')', 'see', 'North', 'Molton', 'U16', 'clinch', 'the', 'North', 'Devon', 'League', 'title', '.', 'Lovely', 'day', 'for', 'it']
# Stemmed Tokens: ['off', 'to', 'woolseri', 'thi', 'morn', 'to', '(', 'hope', ')', 'see', 'north', 'molton', 'u16', 'clinch', 'the', 'north', 'devon', 'leagu', 'titl', '.', 'love', 'day', 'for', 'it']
#
#
# Original Tokens: ['playing', 'singstar', 'without', 'my', 'fave', 'duetter']
# Stemmed Tokens: ['play', 'singstar', 'without', 'my', 'fave', 'duetter']
#
#
# Original Tokens: ['you', '`', 're', 'missing', 'out', ',', 'bb', '!', 'i', '`', 'm', 'such', 'a', 'cereal', 'nut', ',', 'i', 'think', 'i', 'like', 'every', 'kind', 'available', '.']
# Stemmed Tokens: ['you', '`', 're', 'miss', 'out', ',', 'bb', '!', 'i', '`', 'm', 'such', 'a', 'cereal', 'nut', ',', 'i', 'think', 'i', 'like', 'everi', 'kind', 'avail', '.']
#
#
# Original Tokens: ['That', '`', 's', 'just', 'weird', '...', ':', '\\', 'Oh', ',', 'and', 'what', 'was', 'it', 'you', 'were', 'drawing', 'for', 'me', '?']
# Stemmed Tokens: ['that', '`', 's', 'just', 'weird', '...', ':', '\\', 'oh', ',', 'and', 'what', 'wa', 'it', 'you', 'were', 'draw', 'for', 'me', '?']
#
#
# Original Tokens: ['Just', 'woke', 'up', ':', 'o', 'mums', 'singing', 'to', 'her', 'new', 'gn', '`', 'r', 'cd', 'replacement', 'i', 'bought', 'because', 'im', 'a', 'good', 'daughter']
# Stemmed Tokens: ['just', 'woke', 'up', ':', 'o', 'mum', 'sing', 'to', 'her', 'new', 'gn', '`', 'r', 'cd', 'replac', 'i', 'bought', 'becaus', 'im', 'a', 'good', 'daughter']
#
#
# Original Tokens: ['The', 'birds', 'are', 'out', ',', ',', 'oh', 'man', '...', 'That', '`', 's', 'NOT', 'cool', '&', '&', 'I', 'didn', '`', 't', 'sleep', 'yet', 'for', 'the', 'night', '!', '!', '!']
# Stemmed Tokens: ['the', 'bird', 'are', 'out', ',', ',', 'oh', 'man', '...', 'that', '`', 's', 'not', 'cool', '&', '&', 'i', 'didn', '`', 't', 'sleep', 'yet', 'for', 'the', 'night', '!', '!', '!']
#
#
# Original Tokens: ['250', 'miles', 'down', ',', 'only', '1750', 'to', 'go', '.', 'Thats', 'ok', ',', 'u2', 'on', 'the', 'radio', 'alwas', 'helps', '.']
# Stemmed Tokens: ['250', 'mile', 'down', ',', 'onli', '1750', 'to', 'go', '.', 'that', 'ok', ',', 'u2', 'on', 'the', 'radio', 'alwa', 'help', '.']
#
#
# Original Tokens: ['My', 'Street', 'Fighter', 'IV', 'skills', 'are', 'lacking', ',', 'can', '`', 't', 'beat', 'Seth', 'on', 'easy', '.']
# Stemmed Tokens: ['my', 'street', 'fighter', 'iv', 'skill', 'are', 'lack', ',', 'can', '`', 't', 'beat', 'seth', 'on', 'easi', '.']
#
#
# Original Tokens: ['FIL', '461', 'with', 'cool', 'people', 'like', 'me']
# Stemmed Tokens: ['fil', '461', 'with', 'cool', 'peopl', 'like', 'me']
#
#
# Original Tokens: ['Good', 'Morning', '!', '!', '!', 'Work', 'and', 'then', 'it', '`', 's', 'ESPN', '`', 's', 'Sunday', 'night', 'Baseball', '.', 'hopefully', 'it', 'won', '`', 't', 'get', 'rained', 'out']
# Stemmed Tokens: ['good', 'morn', '!', '!', '!', 'work', 'and', 'then', 'it', '`', 's', 'espn', '`', 's', 'sunday', 'night', 'basebal', '.', 'hope', 'it', 'won', '`', 't', 'get', 'rain', 'out']
#
#
# Original Tokens: ['i', 'think', 'it', '`', 's', 'under', 'a', 'honeymoon', 'by', 'the', 'good', 'life', '--', 'either', 'that', 'or', 'it', '`', 's', 'under', 'a', 'honey', 'moon', 'by', 'joseph', 'arthur', '.']
# Stemmed Tokens: ['i', 'think', 'it', '`', 's', 'under', 'a', 'honeymoon', 'by', 'the', 'good', 'life', '--', 'either', 'that', 'or', 'it', '`', 's', 'under', 'a', 'honey', 'moon', 'by', 'joseph', 'arthur', '.']
#
#
# Original Tokens: ['my', 'son', 'got', 'stung', 'by', 'a', 'bug', 'for', 'the', 'first', 'time', 'his', 'little', 'finger', 'is', 'slightly', 'swollen', '.']
# Stemmed Tokens: ['my', 'son', 'got', 'stung', 'by', 'a', 'bug', 'for', 'the', 'first', 'time', 'hi', 'littl', 'finger', 'is', 'slightli', 'swollen', '.']
#
#
# Original Tokens: ['it', 'was', 'hours', 'ago', 'i', 'came', 'in', '....', 'and', 'it', '`', 's', 'only', 'now', 'i', 'realised', 'when', 'i', 'went', 'to', 'buy', 'something', 'online']
# Stemmed Tokens: ['it', 'wa', 'hour', 'ago', 'i', 'came', 'in', '....', 'and', 'it', '`', 's', 'onli', 'now', 'i', 'realis', 'when', 'i', 'went', 'to', 'buy', 'someth', 'onlin']
#
#
# Original Tokens: ['oh', 'just', 'referring', 'to', 'our', 'lil', 'exchange', 'on', 'LJ', 'with', 'regards', 'to', 'twitter', 'archive', 'postings', '.']
# Stemmed Tokens: ['oh', 'just', 'refer', 'to', 'our', 'lil', 'exchang', 'on', 'lj', 'with', 'regard', 'to', 'twitter', 'archiv', 'post', '.']
#
#
# Original Tokens: ['Bumping', 'dj', 'opus', 'in', 'the', 'drunk', 'in', 'the', 'car', '.', 'lmao', '.', 'Don', '`', 't', 'act', 'like', 'u', 'don', '`', 't', 'know', '.']
# Stemmed Tokens: ['bump', 'dj', 'opu', 'in', 'the', 'drunk', 'in', 'the', 'car', '.', 'lmao', '.', 'don', '`', 't', 'act', 'like', 'u', 'don', '`', 't', 'know', '.']
#
#
# Original Tokens: ['Why', 'kiss', 'the', 'feet', 'of', 'the', 'people', 'who', 'kick', 'you', 'when', 'you', 'can', 'be', 'anything', 'that', 'you', 'want', 'to', '?', 'morning', 'everyone', '!', 'Hope', 'you', 'have', 'the', 'best', 'day', 'ever']
# Stemmed Tokens: ['whi', 'kiss', 'the', 'feet', 'of', 'the', 'peopl', 'who', 'kick', 'you', 'when', 'you', 'can', 'be', 'anyth', 'that', 'you', 'want', 'to', '?', 'morn', 'everyon', '!', 'hope', 'you', 'have', 'the', 'best', 'day', 'ever']
#
#
# Original Tokens: ['Here', '`', 's', 'a', 'brief', 'preview', ':', 'OMG', 'James', 'is', 'creepy', 'in', 'that', 'role', '!', 'I', '`', 'm', 'scared', 'of', 'him']
# Stemmed Tokens: ['here', '`', 's', 'a', 'brief', 'preview', ':', 'omg', 'jame', 'is', 'creepi', 'in', 'that', 'role', '!', 'i', '`', 'm', 'scare', 'of', 'him']
#
#
# Original Tokens: ['I', '`', 'm', 'missing', 'crab', 'legs', 'and', 'attending', 'my', 'going', 'away', 'instead', '!']
# Stemmed Tokens: ['i', '`', 'm', 'miss', 'crab', 'leg', 'and', 'attend', 'my', 'go', 'away', 'instead', '!']
#
#
# Original Tokens: ['Hicks', 'are', 'mean', '!']
# Stemmed Tokens: ['hick', 'are', 'mean', '!']
#
#
# Original Tokens: ['gettn', 'ready', 'to', 'take', 'a', 'trip', 'to', 'Jersey', 'my', 'dad', '`', 's', 'not', 'doing', 'so', 'good', ',', 'he', 'needs', 'a', 'new', 'heart~whoeva', 'see', '`', 's', 'this', 'please', 'say', 'a', 'prayer', 'for', 'my', 'dad']
# Stemmed Tokens: ['gettn', 'readi', 'to', 'take', 'a', 'trip', 'to', 'jersey', 'my', 'dad', '`', 's', 'not', 'do', 'so', 'good', ',', 'he', 'need', 'a', 'new', 'heart~whoeva', 'see', '`', 's', 'thi', 'pleas', 'say', 'a', 'prayer', 'for', 'my', 'dad']
#
#
# Original Tokens: ['back', 'soon', ',', 'need', 'to', 'run', 'to', 'the', 'shops', 'and', 'cut', 'the', 'grass']
# Stemmed Tokens: ['back', 'soon', ',', 'need', 'to', 'run', 'to', 'the', 'shop', 'and', 'cut', 'the', 'grass']
#
#
# Original Tokens: ['I', '`', 'm', 'up', '.', 'I', 'have', 'a', 'plan', 'to', 'transform', 'my', 'bedroom', 'today', '.', 'Random', '.']
# Stemmed Tokens: ['i', '`', 'm', 'up', '.', 'i', 'have', 'a', 'plan', 'to', 'transform', 'my', 'bedroom', 'today', '.', 'random', '.']
#
#
# Original Tokens: ['Home', 'until', 'tomorrow', '.', 'Did', 'my', 'running', 'and', 'spinning', '.', 'Now', 'time', 'for', 'chiropractor', ',', 'laundry', ',', 'shopping', ',', 'and', 'visiting', 'family', '.', 'Missing', 'nathan']
# Stemmed Tokens: ['home', 'until', 'tomorrow', '.', 'did', 'my', 'run', 'and', 'spin', '.', 'now', 'time', 'for', 'chiropractor', ',', 'laundri', ',', 'shop', ',', 'and', 'visit', 'famili', '.', 'miss', 'nathan']
#
#
# Original Tokens: ['thats', 'another', 'sponsor']
# Stemmed Tokens: ['that', 'anoth', 'sponsor']
#
#
# Original Tokens: ['And', 'most', 'of', 'us', 'are', 'going', 'to', 'be', 'stuck', 'in', 'an', 'office', ',', 'some', 'without', 'windows']
# Stemmed Tokens: ['and', 'most', 'of', 'us', 'are', 'go', 'to', 'be', 'stuck', 'in', 'an', 'offic', ',', 'some', 'without', 'window']
#
#
# Original Tokens: ['No', 'it', '`', 's', 'not', 'sad', '.', 'Should', 'make', 'you', 'proud']
# Stemmed Tokens: ['no', 'it', '`', 's', 'not', 'sad', '.', 'should', 'make', 'you', 'proud']
#
#
# Original Tokens: ['Sorry', ',', 'we', '`', 'll', 'try', 'to', 'keep', 'it', 'down', '.']
# Stemmed Tokens: ['sorri', ',', 'we', '`', 'll', 'tri', 'to', 'keep', 'it', 'down', '.']
#
#
# Original Tokens: ['is', 'home', 'alone', '..', 'Doing', 'hw']
# Stemmed Tokens: ['is', 'home', 'alon', '..', 'do', 'hw']
#
#
# Original Tokens: ['According', 'to', ',', 'a', 'quarter', 'of', 'families', 'under', 'six', 'live', 'in', 'poverty', '.']
# Stemmed Tokens: ['accord', 'to', ',', 'a', 'quarter', 'of', 'famili', 'under', 'six', 'live', 'in', 'poverti', '.']
#
#
# Original Tokens: ['the', 'plan', 'to', 'not', 'spend', 'money', 'is', 'not', 'going', 'well']
# Stemmed Tokens: ['the', 'plan', 'to', 'not', 'spend', 'money', 'is', 'not', 'go', 'well']
#
#
# Original Tokens: ['uploading', 'all', 'my', 'bamboozle', 'pictures', 'of', 'facebook']
# Stemmed Tokens: ['upload', 'all', 'my', 'bamboozl', 'pictur', 'of', 'facebook']
#
#
# Original Tokens: ['congratulations', '!', 'you', 'guys', 'finish', 'a', 'month', 'early', 'than', 'we', 'do', '.', 'booo']
# Stemmed Tokens: ['congratul', '!', 'you', 'guy', 'finish', 'a', 'month', 'earli', 'than', 'we', 'do', '.', 'booo']
#
#
# Original Tokens: ['actually', ',', 'I', 'wish', 'I', 'was', 'back', 'in', 'Tahoe', '.', 'I', 'miss', 'it', 'there', '.']
# Stemmed Tokens: ['actual', ',', 'i', 'wish', 'i', 'wa', 'back', 'in', 'taho', '.', 'i', 'miss', 'it', 'there', '.']
